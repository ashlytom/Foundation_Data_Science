# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

heights=pd.read_csv("/home/ashly/Desktop/FDS/Lab Assignments/Lab FDS 7-10-20/CSV Files/galton.csv")
heights.head()
heights_sub=heights.drop(columns=["family","midparentHeight","children","childNum","gender"])
heights_sub=heights_sub.rename(columns={'childHeight':'son'})
heights_sub
# Out:
#      father  mother   son
# 0      78.5    67.0  73.2
# 1      78.5    67.0  69.2
# 2      78.5    67.0  69.0
# 3      78.5    67.0  69.0
# 4      75.5    66.5  73.5
# ..      ...     ...   ...
# 929    62.0    66.0  64.0
# 930    62.0    66.0  62.0
# 931    62.0    66.0  61.0
# 932    62.5    63.0  66.5
# 933    62.5    63.0  57.0
#
# [934 rows x 3 columns]

# %%
plt.figure(figsize=(10,10))
plt.scatter(heights_sub.son,heights_sub.father)
plt.scatter(heights_sub.son,heights_sub.mother)

# %% [markdown]
# #### Line Plots

# %%
census=pd.read_csv('/home/ashly/Desktop/FDS/Lab Assignments/Lab FDS 7-10-20/CSV Files/census.csv')
census=census.drop(columns=['ESTIMATESBASE2010','CENSUS2010POP','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2015'])
census=census.rename(columns={'POPESTIMATE2010':'2010','POPESTIMATE2014':'2014'})
children=census.loc[census['SEX']==0]
children=children.loc[children.AGE<=18].drop(columns='SEX')
children
# Out:
#     AGE     2010     2014
# 0     0  3951330  3949775
# 1     1  3957888  3949776
# 2     2  4090862  3959664
# 3     3  4111920  4007079
# 4     4  4077551  4005716
# 5     5  4064653  4006900
# 6     6  4073013  4135930
# 7     7  4043046  4155326
# 8     8  4025604  4120903
# 9     9  4125415  4108349
# 10   10  4187062  4116942
# 11   11  4115511  4087402
# 12   12  4113279  4070682
# 13   13  4119666  4171030
# 14   14  4145614  4233839
# 15   15  4231002  4164796
# 16   16  4313252  4168559
# 17   17  4376367  4186513
# 18   18  4491005  4227920

# %%
plt.figure(figsize=(10,10))
plt.plot(children.AGE,children['2010'])
plt.plot(children.AGE,children['2014'])

# %% [markdown]
# #### BAR PLOTS

# %%
usa_ca=pd.read_csv('/home/ashly/Desktop/FDS/Lab Assignments/Lab FDS 7-10-20/CSV Files/Untitled 1.csv')
usa_ca
# Out:
#   Ethnicity  USA All  CA All  USA Children  CA Children
# 0     Black     0.12    0.05          0.14         0.05
# 1  Hispanic     0.18    0.38          0.24         0.50
# 2     White     0.62    0.39          0.52         0.29
# 3     Other     0.08    0.18          0.10         0.16

# %%
usa_ca.plot(x='Ethnicity', y=['USA All','CA All','USA Children','CA Children'], kind="barh")
# Out:
# <AxesSubplot:ylabel='Ethnicity'>

# %%
usa_ca.plot(x='Ethnicity', y=['USA All','CA All'], kind="barh")
# Out:
# <AxesSubplot:ylabel='Ethnicity'>

# %%
usa_ca.plot(x='Ethnicity', y=['CA All','CA Children'], kind="barh")
# Out:
# <AxesSubplot:ylabel='Ethnicity'>

# %% [markdown]
# Chapter 7 Completed
